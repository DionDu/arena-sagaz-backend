# %% [markdown]
# # Arena Sagaz — Treinamento CNN V3 (Auto-Play Dataset)
#
# Versão V3 do notebook de treino, compatível com datasets gerados pelo
# `Otimizacao_Topologia_Rede_V3.ipynb` (auto-play Minimax).
#
# **Mudanças em relação ao notebook anterior:**
# - Leitura do campo `generation_mode` (0=random, 1=p1, 2=p2, 3=p3)
# - Suporte opcional a `sample_weight` ponderado por `generation_mode`
# - Métricas (Top-1/Top-3/Top-5/OMA) **por generation_mode** na avaliação
# - Histograma de distribuição das amostras por modo
# - Compatível com datasets V2 sem `generation_mode` (fallback mode=0)

# %%
# =========================================================================
# CONFIGURACAO — edite aqui antes de rodar
# =========================================================================
from google.colab import drive
drive.mount('/content/drive')

# Pasta no Drive onde o .tflite será salvo (criada automaticamente)
DRIVE_OUTPUT_DIR = '/content/drive/MyDrive/arena-sagaz/modelos'

# Pasta local dos NPZ — aponte para onde fez upload dos dados
PASTA_NPZ = '../dados/profundidade_minmax_9'

import os
os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)
print(f"Drive montado. Modelos serao salvos em: {DRIVE_OUTPUT_DIR}")
print(f"Lendo NPZ de: {PASTA_NPZ}")

# %%
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Reduz logs internos do TensorFlow para deixar a saída do notebook mais limpa.
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
sns.set_theme(style="whitegrid")

# Sementes fixas para reprodutibilidade dos experimentos.
np.random.seed(42)
tf.keras.utils.set_random_seed(42)

print("TensorFlow:", tf.__version__)
print("GPU disponível:", len(tf.config.list_physical_devices('GPU')) > 0)
# Out:
# TensorFlow: 2.19.0
# GPU disponível: True

# %% [markdown]
# # =========================================================================
# # 1.1 LEITURA DOS LOTES
# # =========================================================================
# import os, glob
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import tensorflow as tf
# from tensorflow.keras import layers, models, regularizers, Input
# from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import classification_report
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
#
# MODE_NAMES = {0: 'random(p=0)', 1: 'autoplay(p=1)', 2: 'autoplay(p=2)', 3: 'autoplay(p=3)'}
#
# # Configuracao de pesos por generation_mode (sample_weight).
# # Defina USE_SAMPLE_WEIGHT = False para treinar sem pesos (recomendado como baseline).
# USE_SAMPLE_WEIGHT = False
# MODE_WEIGHTS = {0: 1.0, 1: 2.0, 2: 3.0, 3: 3.0}  # ajuste conforme resultados
#
# arquivos_npz = sorted(glob.glob(os.path.join(PASTA_NPZ, '*.npz')))
# if not arquivos_npz:
#     arquivos_npz = sorted(glob.glob('*.npz'))
# print(f'Encontrados {len(arquivos_npz)} arquivos.')
#
# lista_estados, lista_rotulos, lista_scores, lista_gen_modes = [], [], [], []
# labels_canonicos = None
#
# for arquivo in arquivos_npz:
#     dados = np.load(arquivo, allow_pickle=True)
#     lista_estados.append(dados['estados'])
#     lista_rotulos.append(dados['rotulos'])
#     lista_scores.append(dados['scores'])
#     # Compatibilidade com datasets V2 (sem generation_mode)
#     if 'generation_mode' in dados:
#         lista_gen_modes.append(dados['generation_mode'])
#     else:
#         lista_gen_modes.append(np.zeros(len(dados['estados']), dtype=np.int8))
#     if labels_canonicos is None:
#         labels_canonicos = dados['labels_canonicos'].tolist()
#
# X_raw        = np.concatenate(lista_estados,   axis=0).astype(np.float32)
# y_str        = np.concatenate(lista_rotulos,   axis=0)
# scores_raw   = np.concatenate(lista_scores,    axis=0)
# gen_modes    = np.concatenate(lista_gen_modes, axis=0).astype(np.int8)
#
# print(f'Total de amostras: {len(X_raw):,}')
# print(f'Shape entrada: {X_raw.shape} | Scores: {scores_raw.shape}')
#
# # Distribuicao por generation_mode
# print('\nDistribuicao por generation_mode:')
# for m in sorted(set(gen_modes.tolist())):
#     n = (gen_modes == m).sum()
#     print(f'  {MODE_NAMES.get(m, str(m))}: {n:,} ({n/len(gen_modes)*100:.1f}%)')
#
# # =========================================================================
# # 1.2 NORMALIZACAO
# # =========================================================================
# X_raw[X_raw == 8] = 0.0   # pontos fixos -> 0
# X_raw[X_raw == 9] = 1.0   # arestas -> 1 (V3 e V2 normalizados)
#
# # =========================================================================
# # 1.3 SOFT TARGETS (KL Divergence)
# # =========================================================================
# SCORE_IND = -1e9
# label_to_idx = {l: i for i, l in enumerate(labels_canonicos)}
# num_classes = len(labels_canonicos)
# indice_para_rotulo = {i: l for i, l in enumerate(labels_canonicos)}
# T = 1.0  # temperatura
# y_soft = np.zeros((len(scores_raw), num_classes), dtype=np.float32)
#
# for i, sv in enumerate(scores_raw):
#     mask = sv > SCORE_IND
#     if mask.sum() == 0:
#         y_soft[i] = 1.0 / num_classes
#         continue
#     vals = sv[mask] / T
#     vals -= vals.max()
#     exp_v = np.exp(vals)
#     y_soft[i, mask] = exp_v / exp_v.sum()
#
# y_idx = y_soft.argmax(axis=1)
#
# # Tensor de entrada: adiciona dim de canal
# X = X_raw[..., np.newaxis]
#
# # =========================================================================
# # 1.4 SPLIT 70/15/15
# # =========================================================================
# idx_all = np.arange(len(X))
# idx_tv, idx_test = train_test_split(idx_all, test_size=0.15, random_state=42)
# idx_train, idx_val = train_test_split(idx_tv,  test_size=0.15/0.85, random_state=42)
#
# X_train, y_train = X[idx_train], y_soft[idx_train]
# X_val,   y_val   = X[idx_val],   y_soft[idx_val]
# X_test,  y_test  = X[idx_test],  y_soft[idx_test]
# y_test_idx       = y_idx[idx_test]
# gen_test         = gen_modes[idx_test]
# S_test           = scores_raw[idx_test]
#
# # sample_weight (opcional)
# if USE_SAMPLE_WEIGHT:
#     sw = np.array([MODE_WEIGHTS.get(int(m), 1.0) for m in gen_modes[idx_train]], dtype=np.float32)
#     print(f'sample_weight ativado: pesos {MODE_WEIGHTS}')
# else:
#     sw = None
#
# print(f'\nTreino: {len(X_train):,}  |  Val: {len(X_val):,}  |  Teste: {len(X_test):,}')

# %%
# =========================================================================
# 1.1 LEITURA DOS LOTES
# =========================================================================
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

MODE_NAMES = {0: 'random(p=0)', 1: 'autoplay(p=1)', 2: 'autoplay(p=2)', 3: 'autoplay(p=3)'}

# Configuracao de pesos por generation_mode (sample_weight).
# Defina USE_SAMPLE_WEIGHT = False para treinar sem pesos (recomendado como baseline).
USE_SAMPLE_WEIGHT = False
MODE_WEIGHTS = {0: 1.0, 1: 2.0, 2: 3.0, 3: 3.0}  # ajuste conforme resultados

arquivos_npz = sorted(glob.glob('../dados_v3/*.npz'))
if not arquivos_npz:
    arquivos_npz = sorted(glob.glob('*.npz'))
print(f'Encontrados {len(arquivos_npz)} arquivos.')

lista_estados, lista_rotulos, lista_scores, lista_gen_modes = [], [], [], []
labels_canonicos = None

for arquivo in arquivos_npz:
    dados = np.load(arquivo, allow_pickle=True)
    lista_estados.append(dados['estados'])
    lista_rotulos.append(dados['rotulos'])
    lista_scores.append(dados['scores'])
    # Compatibilidade com datasets V2 (sem generation_mode)
    if 'generation_mode' in dados:
        lista_gen_modes.append(dados['generation_mode'])
    else:
        lista_gen_modes.append(np.zeros(len(dados['estados']), dtype=np.int8))
    if labels_canonicos is None:
        labels_canonicos = dados['labels_canonicos'].tolist()

X_raw        = np.concatenate(lista_estados,   axis=0).astype(np.float32)
y_str        = np.concatenate(lista_rotulos,   axis=0)
scores_raw   = np.concatenate(lista_scores,    axis=0)
gen_modes    = np.concatenate(lista_gen_modes, axis=0).astype(np.int8)

print(f'Total de amostras: {len(X_raw):,}')
print(f'Shape entrada: {X_raw.shape} | Scores: {scores_raw.shape}')

# Distribuicao por generation_mode
print('\nDistribuicao por generation_mode:')
for m in sorted(set(gen_modes.tolist())):
    n = (gen_modes == m).sum()
    print(f'  {MODE_NAMES.get(m, str(m))}: {n:,} ({n/len(gen_modes)*100:.1f}%)')

# =========================================================================
# 1.2 NORMALIZACAO
# =========================================================================
X_raw[X_raw == 8] = 0.0   # pontos fixos -> 0
X_raw[X_raw == 9] = 1.0   # arestas -> 1 (V3 e V2 normalizados)

# =========================================================================
# 1.3 SOFT TARGETS (KL Divergence)
# =========================================================================
SCORE_IND = -1e9
label_to_idx = {l: i for i, l in enumerate(labels_canonicos)}
num_classes = len(labels_canonicos)
indice_para_rotulo = {i: l for i, l in enumerate(labels_canonicos)}
T = 1.0  # temperatura
y_soft = np.zeros((len(scores_raw), num_classes), dtype=np.float32)

for i, sv in enumerate(scores_raw):
    mask = sv > SCORE_IND
    if mask.sum() == 0:
        y_soft[i] = 1.0 / num_classes
        continue
    vals = sv[mask] / T
    vals -= vals.max()
    exp_v = np.exp(vals)
    y_soft[i, mask] = exp_v / exp_v.sum()

y_idx = y_soft.argmax(axis=1)

# Tensor de entrada: adiciona dim de canal
X = X_raw[..., np.newaxis]

# =========================================================================
# 1.4 SPLIT 70/15/15
# =========================================================================
idx_all = np.arange(len(X))
idx_tv, idx_test = train_test_split(idx_all, test_size=0.15, random_state=42)
idx_train, idx_val = train_test_split(idx_tv,  test_size=0.15/0.85, random_state=42)

X_train, y_train = X[idx_train], y_soft[idx_train]
X_val,   y_val   = X[idx_val],   y_soft[idx_val]
X_test,  y_test  = X[idx_test],  y_soft[idx_test]
y_test_idx       = y_idx[idx_test]
gen_test         = gen_modes[idx_test]
S_test           = scores_raw[idx_test]  # <--- Essa linha foi adicionada

# sample_weight (opcional)
if USE_SAMPLE_WEIGHT:
    sw = np.array([MODE_WEIGHTS.get(int(m), 1.0) for m in gen_modes[idx_train]], dtype=np.float32)
    print(f'sample_weight ativado: pesos {MODE_WEIGHTS}')
else:
    sw = None

print(f'\nTreino: {len(X_train):,}  |  Val: {len(X_val):,}  |  Teste: {len(X_test):,}')
# Out:
# Encontrados 60 arquivos.
# Total de amostras: 357,000
# Shape entrada: (357000, 9, 7) | Scores: (357000, 31)
#
# Distribuicao por generation_mode:
#   random(p=0): 53,324 (14.9%)
#   autoplay(p=1): 88,946 (24.9%)
#   autoplay(p=2): 197,052 (55.2%)
#   autoplay(p=3): 17,678 (5.0%)
#
# Treino: 249,900  |  Val: 53,550  |  Teste: 53,550

# %% [markdown]
# ## 2. Arquitetura `BoxNet v3` — CNN Centrada em Caixas com Soft Targets
#
# ### Histórico de experimentos
#
# | Rodada | Dataset | Prof. | Dados | top-1 | top-3 | top-5 | OMA | Loss | Observação principal |
# |--------|---------|-------|-------|-------|-------|-------|-----|------|----------------------|
# | CNN ingênua | Aleatorio | 3 | 50k | ~11% | — | — | — | CE | Abaixo do aleatório (1/31≈3.2%) — bug de mapeamento |
# | MLP flat | Aleatorio | 5 | 50k | ~18% | — | — | — | CE | Sem captura de estrutura espacial |
# | BoxNet v1 | Aleatorio | 5 | 50k | ~28% | ~58% | ~74% | — | CE | Plateau prematuro; argmax ambíguo |
# | BoxNet v2 (argmax) | Aleatorio | 5 | 210k | ~36% | ~70% | ~83% | — | CE | Gap treino/val ≈9.6pp — soft targets necessários |
# | BoxNet v3 R1 (KLD) | Q-values | 5 | 210k | ~35% | ~69% | ~82% | 99% | KLD | OMA=99%: top-1 mede desempate, não qualidade |
# | BoxNet v3 R2 (T=0.5) | Q-values | 5 | 210k | ~33% | ~67% | ~80% | 99% | KLD | T=0.5 não ajuda (empates uniformes independem de T) |
# | BoxNet v3 R3 (sw) | Q-values | 5 | 300k | ~31% | ~64% | ~79% | ~99% | KLD | sample_weight por freq. de classe causou regressão |
# | BoxNet v3 R4 (T=1.0) | Q-values | 6 | 300k | ~35% | ~68% | ~81% | ~99% | KLD | Referência: win-rate vs MM(p=1)=96%, MM(p=3)=52% |
# | BoxNet v3 R5 | Q-values | 7 | 300k | ~34% | ~68% | ~82% | ~99% | KLD | depth-7 **piorou** vs MM(p=1)=89%, MM(p=3)=45% |
# | **BoxNet V3-AutoPlay** | **Auto-play** | **7** | **300k** | **?** | **?** | **?** | **?** | KLD | **Esta rodada** — dataset auto-play, estimativa: MM(p=3)~75-85% |
#
# > **Por que top-1 ≈ 34% é aceitável**: com 31 traços possíveis, estados de abertura têm múltiplas
# > jogadas Minimax-equivalentes. A CNN pode escolher qualquer uma delas (OMA=99%) mas o rótulo
# > canônico registra apenas uma — deprimindo o top-1 artificialmente.
# >
# > **Por que depth-7 aleatório piorou vs depth-6**: o professor mais preciso aprendeu nuances de
# > posições irreais (geradas por shuffle aleatório). O dataset auto-play resolve essa causa raiz.
# > Ver `docs/historico_decisoes.md` para análise completa.

# %%
# =========================================================================
# CAMADA 0 — TRANSFORMAÇÃO GEOMÉTRICA (9,7,1) → (4,3,5)
# Reorganiza a matriz crua em grid centrado em CAIXAS.
# Convenção canônica (vide gerador_dados/tabuleiro.py):
#   linha PAR  + coluna ÍMPAR → traço Horizontal
#   linha ÍMPAR + coluna PAR  → traço Vertical
#   linha ÍMPAR + coluna ÍMPAR → interior da caixa
# =========================================================================
def para_grid_de_caixas(x):
    x = tf.squeeze(x, axis=-1)                # (B, 9, 7)
    topo     = x[:, 0:8:2, 1:7:2]             # (B,4,3) traço H acima
    base     = x[:, 2:9:2, 1:7:2]             # (B,4,3) traço H abaixo
    esquerda = x[:, 1:8:2, 0:6:2]             # (B,4,3) traço V à esquerda
    direita  = x[:, 1:8:2, 2:7:2]             # (B,4,3) traço V à direita
    interior = x[:, 1:8:2, 1:7:2]             # (B,4,3) dono da caixa
    return tf.stack([topo, base, esquerda, direita, interior], axis=-1)  # (B,4,3,5)


def bloco_residual_separavel(x, filtros, l2=2e-4, dropout=0.15):
    """Bloco residual: 2× SeparableConv2D 3×3 + BN + skip connection."""
    atalho = x
    y = layers.SeparableConv2D(
        filtros, (3, 3), padding='same', use_bias=False,
        depthwise_regularizer=regularizers.l2(l2),
        pointwise_regularizer=regularizers.l2(l2),
    )(x)
    y = layers.BatchNormalization()(y)
    y = layers.Activation('relu')(y)
    y = layers.SpatialDropout2D(dropout)(y)

    y = layers.SeparableConv2D(
        filtros, (3, 3), padding='same', use_bias=False,
        depthwise_regularizer=regularizers.l2(l2),
        pointwise_regularizer=regularizers.l2(l2),
    )(y)
    y = layers.BatchNormalization()(y)

    if atalho.shape[-1] != filtros:
        atalho = layers.Conv2D(filtros, (1, 1), padding='same', use_bias=False,
                               kernel_regularizer=regularizers.l2(l2))(atalho)
        atalho = layers.BatchNormalization()(atalho)

    out = layers.Add()([y, atalho])
    out = layers.Activation('relu')(out)
    return out


# =========================================================================
# ARQUITETURA BoxNet v3 — idêntica à v2, mas treinada com KL Divergence
# =========================================================================
L2 = 2e-4

inputs = Input(shape=(9, 7, 1), name='tabuleiro_cru')

x = layers.Lambda(para_grid_de_caixas, name='grid_de_caixas')(inputs)

x = layers.Conv2D(32, (3, 3), padding='same', use_bias=False,
                  kernel_regularizer=regularizers.l2(L2))(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

x = bloco_residual_separavel(x, 32, l2=L2, dropout=0.15)
x = bloco_residual_separavel(x, 48, l2=L2, dropout=0.20)

gap  = layers.GlobalAveragePooling2D()(x)
flat = layers.Flatten()(x)
h    = layers.Concatenate()([gap, flat])
h    = layers.Dense(96, activation='relu', kernel_regularizer=regularizers.l2(L2))(h)
h    = layers.BatchNormalization()(h)
h    = layers.Dropout(0.5)(h)

outputs = layers.Dense(num_classes, activation='softmax',
                       kernel_regularizer=regularizers.l2(L2),
                       name='jogada')(h)

model = models.Model(inputs, outputs, name='BoxNet_v3_ArenaSagaz')

# KLDivergence: mede distância entre a distribuição prevista e o soft target.
# Não usar label_smoothing — os soft targets já codificam suavização via Q-values.
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss=tf.keras.losses.KLDivergence(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=3, name='top3_acc'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top5_acc'),
    ],
)

model.summary()
# Out:
# Model: "BoxNet_v3_ArenaSagaz"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ tabuleiro_cru       │ (None, 9, 7, 1)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ grid_de_caixas      │ (None, 4, 3, 5)   │          0 │ tabuleiro_cru[0]… │
# │ (Lambda)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 3, 32)  │      1,440 │ grid_de_caixas[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 32)  │        128 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 4, 3, 32)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 4, 3, 32)  │      1,312 │ activation_5[0][… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 32)  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 4, 3, 32)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 4, 3, 32)  │          0 │ activation_6[0][… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 4, 3, 32)  │      1,312 │ spatial_dropout2… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 32)  │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 4, 3, 32)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 4, 3, 32)  │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 4, 3, 48)  │      1,824 │ activation_7[0][… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 48)  │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 4, 3, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 4, 3, 48)  │          0 │ activation_8[0][… │
# │ (SpatialDropout2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 4, 3, 48)  │      2,736 │ spatial_dropout2… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 3, 48)  │      1,536 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 48)  │        192 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 3, 48)  │        192 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 3, 48)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 4, 3, 48)  │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ activation_9[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 576)       │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 624)       │          0 │ global_average_p… │
# │ (Concatenate)       │                   │            │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 96)        │     60,000 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96)        │        384 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 96)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ jogada (Dense)      │ (None, 31)        │      3,007 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 74,511 (291.06 KB)
#  Trainable params: 73,839 (288.43 KB)
#  Non-trainable params: 672 (2.62 KB)

# %%
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-5, verbose=1),
]

history = model.fit(
    X_train, y_train,
    epochs=120,
    batch_size=256,
    validation_data=(X_val, y_val),
    sample_weight=sw,   # None se USE_SAMPLE_WEIGHT=False
    callbacks=callbacks,
    verbose=2,
)
# Out:
# Epoch 1/120
# 977/977 - 33s - 34ms/step - accuracy: 0.2248 - loss: 1.0543 - top3_acc: 0.3927 - top5_acc: 0.4940 - val_accuracy: 0.3807 - val_loss: 0.4960 - val_top3_acc: 0.5841 - val_top5_acc: 0.6846 - learning_rate: 0.0010
# Epoch 2/120
# 977/977 - 6s - 6ms/step - accuracy: 0.3684 - loss: 0.5631 - top3_acc: 0.5755 - top5_acc: 0.6729 - val_accuracy: 0.3731 - val_loss: 0.3747 - val_top3_acc: 0.5853 - val_top5_acc: 0.6642 - learning_rate: 0.0010
# Epoch 3/120
# 977/977 - 6s - 6ms/step - accuracy: 0.3793 - loss: 0.4720 - top3_acc: 0.5982 - top5_acc: 0.6939 - val_accuracy: 0.4087 - val_loss: 0.3142 - val_top3_acc: 0.6432 - val_top5_acc: 0.7417 - learning_rate: 0.0010
# Epoch 4/120
# 977/977 - 6s - 6ms/step - accuracy: 0.3855 - loss: 0.4188 - top3_acc: 0.6059 - top5_acc: 0.7012 - val_accuracy: 0.3932 - val_loss: 0.2933 - val_top3_acc: 0.6169 - val_top5_acc: 0.7090 - learning_rate: 0.0010
# Epoch 5/120
# 977/977 - 6s - 6ms/step - accuracy: 0.3890 - loss: 0.3886 - top3_acc: 0.6093 - top5_acc: 0.7034 - val_accuracy: 0.3896 - val_loss: 0.2604 - val_top3_acc: 0.5987 - val_top5_acc: 0.6907 - learning_rate: 0.0010
# Epoch 6/120
# 977/977 - 6s - 6ms/step - accuracy: 0.3937 - loss: 0.3673 - top3_acc: 0.6133 - top5_acc: 0.7078 - val_accuracy: 0.4178 - val_loss: 0.2438 - val_top3_acc: 0.6217 - val_top5_acc: 0.7100 - learning_rate: 0.0010
# Epoch 7/120
# 977/977 - 7s - 7ms/step - accuracy: 0.3961 - loss: 0.3513 - top3_acc: 0.6125 - top5_acc: 0.7081 - val_accuracy: 0.4278 - val_loss: 0.2442 - val_top3_acc: 0.6367 - val_top5_acc: 0.7368 - learning_rate: 0.0010
# Epoch 8/120
# 977/977 - 8s - 8ms/step - accuracy: 0.3980 - loss: 0.3426 - top3_acc: 0.6160 - top5_acc: 0.7097 - val_accuracy: 0.4287 - val_loss: 0.2271 - val_top3_acc: 0.6723 - val_top5_acc: 0.8015 - learning_rate: 0.0010
# Epoch 9/120
# 977/977 - 8s - 8ms/step - accuracy: 0.4003 - loss: 0.3354 - top3_acc: 0.6162 - top5_acc: 0.7104 - val_accuracy: 0.4072 - val_loss: 0.2173 - val_top3_acc: 0.6157 - val_top5_acc: 0.7169 - learning_rate: 0.0010
# Epoch 10/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4019 - loss: 0.3308 - top3_acc: 0.6181 - top5_acc: 0.7127 - val_accuracy: 0.4276 - val_loss: 0.2161 - val_top3_acc: 0.6712 - val_top5_acc: 0.7999 - learning_rate: 0.0010
# Epoch 11/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4032 - loss: 0.3274 - top3_acc: 0.6175 - top5_acc: 0.7125 - val_accuracy: 0.4120 - val_loss: 0.2161 - val_top3_acc: 0.6227 - val_top5_acc: 0.7083 - learning_rate: 0.0010
# Epoch 12/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4028 - loss: 0.3236 - top3_acc: 0.6180 - top5_acc: 0.7123 - val_accuracy: 0.4204 - val_loss: 0.2087 - val_top3_acc: 0.6321 - val_top5_acc: 0.7224 - learning_rate: 0.0010
# Epoch 13/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4035 - loss: 0.3203 - top3_acc: 0.6173 - top5_acc: 0.7133 - val_accuracy: 0.4535 - val_loss: 0.2090 - val_top3_acc: 0.7467 - val_top5_acc: 0.8891 - learning_rate: 0.0010
# Epoch 14/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4037 - loss: 0.3182 - top3_acc: 0.6191 - top5_acc: 0.7139 - val_accuracy: 0.4246 - val_loss: 0.2035 - val_top3_acc: 0.6391 - val_top5_acc: 0.7226 - learning_rate: 0.0010
# Epoch 15/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4052 - loss: 0.3159 - top3_acc: 0.6190 - top5_acc: 0.7140 - val_accuracy: 0.4045 - val_loss: 0.2067 - val_top3_acc: 0.6717 - val_top5_acc: 0.8144 - learning_rate: 0.0010
# Epoch 16/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4051 - loss: 0.3139 - top3_acc: 0.6183 - top5_acc: 0.7127 - val_accuracy: 0.4382 - val_loss: 0.2110 - val_top3_acc: 0.6456 - val_top5_acc: 0.7197 - learning_rate: 0.0010
# Epoch 17/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4061 - loss: 0.3126 - top3_acc: 0.6186 - top5_acc: 0.7136 - val_accuracy: 0.4152 - val_loss: 0.1981 - val_top3_acc: 0.6376 - val_top5_acc: 0.7418 - learning_rate: 0.0010
# Epoch 18/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4063 - loss: 0.3117 - top3_acc: 0.6197 - top5_acc: 0.7153 - val_accuracy: 0.3902 - val_loss: 0.2054 - val_top3_acc: 0.5965 - val_top5_acc: 0.6706 - learning_rate: 0.0010
# Epoch 19/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4063 - loss: 0.3102 - top3_acc: 0.6192 - top5_acc: 0.7135 - val_accuracy: 0.4330 - val_loss: 0.1950 - val_top3_acc: 0.6934 - val_top5_acc: 0.8219 - learning_rate: 0.0010
# Epoch 20/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4066 - loss: 0.3085 - top3_acc: 0.6198 - top5_acc: 0.7136 - val_accuracy: 0.3938 - val_loss: 0.1979 - val_top3_acc: 0.6134 - val_top5_acc: 0.7103 - learning_rate: 0.0010
# Epoch 21/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4065 - loss: 0.3077 - top3_acc: 0.6192 - top5_acc: 0.7148 - val_accuracy: 0.4287 - val_loss: 0.1936 - val_top3_acc: 0.6480 - val_top5_acc: 0.7334 - learning_rate: 0.0010
# Epoch 22/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4061 - loss: 0.3064 - top3_acc: 0.6206 - top5_acc: 0.7142 - val_accuracy: 0.4311 - val_loss: 0.1960 - val_top3_acc: 0.6213 - val_top5_acc: 0.7023 - learning_rate: 0.0010
# Epoch 23/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4064 - loss: 0.3052 - top3_acc: 0.6191 - top5_acc: 0.7143 - val_accuracy: 0.3987 - val_loss: 0.1933 - val_top3_acc: 0.6139 - val_top5_acc: 0.7109 - learning_rate: 0.0010
# Epoch 24/120
# 977/977 - 7s - 7ms/step - accuracy: 0.4066 - loss: 0.3048 - top3_acc: 0.6197 - top5_acc: 0.7141 - val_accuracy: 0.4603 - val_loss: 0.1906 - val_top3_acc: 0.7162 - val_top5_acc: 0.8263 - learning_rate: 0.0010
# Epoch 25/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4069 - loss: 0.3036 - top3_acc: 0.6199 - top5_acc: 0.7142 - val_accuracy: 0.4123 - val_loss: 0.1895 - val_top3_acc: 0.6114 - val_top5_acc: 0.6947 - learning_rate: 0.0010
# Epoch 26/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4064 - loss: 0.3033 - top3_acc: 0.6195 - top5_acc: 0.7135 - val_accuracy: 0.4218 - val_loss: 0.1905 - val_top3_acc: 0.6351 - val_top5_acc: 0.7361 - learning_rate: 0.0010
# Epoch 27/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4073 - loss: 0.3031 - top3_acc: 0.6202 - top5_acc: 0.7134 - val_accuracy: 0.4032 - val_loss: 0.1888 - val_top3_acc: 0.6187 - val_top5_acc: 0.7171 - learning_rate: 0.0010
# Epoch 28/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4070 - loss: 0.3013 - top3_acc: 0.6200 - top5_acc: 0.7156 - val_accuracy: 0.4046 - val_loss: 0.1826 - val_top3_acc: 0.6114 - val_top5_acc: 0.7166 - learning_rate: 0.0010
# Epoch 29/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4077 - loss: 0.3009 - top3_acc: 0.6209 - top5_acc: 0.7158 - val_accuracy: 0.4152 - val_loss: 0.1837 - val_top3_acc: 0.6453 - val_top5_acc: 0.7446 - learning_rate: 0.0010
# Epoch 30/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4067 - loss: 0.3004 - top3_acc: 0.6200 - top5_acc: 0.7148 - val_accuracy: 0.4140 - val_loss: 0.1895 - val_top3_acc: 0.6387 - val_top5_acc: 0.7329 - learning_rate: 0.0010
# Epoch 31/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4071 - loss: 0.3005 - top3_acc: 0.6199 - top5_acc: 0.7148 - val_accuracy: 0.4103 - val_loss: 0.1886 - val_top3_acc: 0.5979 - val_top5_acc: 0.6730 - learning_rate: 0.0010
# Epoch 32/120
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 977/977 - 6s - 6ms/step - accuracy: 0.4079 - loss: 0.2996 - top3_acc: 0.6208 - top5_acc: 0.7158 - val_accuracy: 0.4115 - val_loss: 0.1878 - val_top3_acc: 0.6270 - val_top5_acc: 0.7219 - learning_rate: 0.0010
# Epoch 33/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4099 - loss: 0.2889 - top3_acc: 0.6206 - top5_acc: 0.7156 - val_accuracy: 0.4168 - val_loss: 0.1757 - val_top3_acc: 0.6140 - val_top5_acc: 0.6949 - learning_rate: 5.0000e-04
# Epoch 34/120
# 977/977 - 11s - 11ms/step - accuracy: 0.4106 - loss: 0.2857 - top3_acc: 0.6223 - top5_acc: 0.7171 - val_accuracy: 0.4238 - val_loss: 0.1751 - val_top3_acc: 0.6347 - val_top5_acc: 0.7407 - learning_rate: 5.0000e-04
# Epoch 35/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4100 - loss: 0.2849 - top3_acc: 0.6225 - top5_acc: 0.7165 - val_accuracy: 0.4277 - val_loss: 0.1729 - val_top3_acc: 0.6586 - val_top5_acc: 0.7742 - learning_rate: 5.0000e-04
# Epoch 36/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4097 - loss: 0.2844 - top3_acc: 0.6220 - top5_acc: 0.7171 - val_accuracy: 0.4297 - val_loss: 0.1678 - val_top3_acc: 0.6344 - val_top5_acc: 0.7347 - learning_rate: 5.0000e-04
# Epoch 37/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4099 - loss: 0.2840 - top3_acc: 0.6227 - top5_acc: 0.7168 - val_accuracy: 0.4610 - val_loss: 0.1717 - val_top3_acc: 0.7159 - val_top5_acc: 0.8234 - learning_rate: 5.0000e-04
# Epoch 38/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4098 - loss: 0.2830 - top3_acc: 0.6226 - top5_acc: 0.7164 - val_accuracy: 0.4545 - val_loss: 0.1732 - val_top3_acc: 0.7032 - val_top5_acc: 0.8123 - learning_rate: 5.0000e-04
# Epoch 39/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4104 - loss: 0.2829 - top3_acc: 0.6226 - top5_acc: 0.7177 - val_accuracy: 0.4221 - val_loss: 0.1704 - val_top3_acc: 0.6319 - val_top5_acc: 0.7211 - learning_rate: 5.0000e-04
# Epoch 40/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4105 - loss: 0.2819 - top3_acc: 0.6222 - top5_acc: 0.7173 - val_accuracy: 0.4415 - val_loss: 0.1659 - val_top3_acc: 0.6488 - val_top5_acc: 0.7504 - learning_rate: 5.0000e-04
# Epoch 41/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4098 - loss: 0.2818 - top3_acc: 0.6220 - top5_acc: 0.7163 - val_accuracy: 0.4652 - val_loss: 0.1663 - val_top3_acc: 0.7257 - val_top5_acc: 0.8443 - learning_rate: 5.0000e-04
# Epoch 42/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4105 - loss: 0.2815 - top3_acc: 0.6222 - top5_acc: 0.7169 - val_accuracy: 0.4193 - val_loss: 0.1680 - val_top3_acc: 0.6311 - val_top5_acc: 0.7221 - learning_rate: 5.0000e-04
# Epoch 43/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4103 - loss: 0.2810 - top3_acc: 0.6207 - top5_acc: 0.7149 - val_accuracy: 0.4399 - val_loss: 0.1664 - val_top3_acc: 0.6317 - val_top5_acc: 0.7136 - learning_rate: 5.0000e-04
# Epoch 44/120
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 977/977 - 10s - 11ms/step - accuracy: 0.4109 - loss: 0.2809 - top3_acc: 0.6222 - top5_acc: 0.7169 - val_accuracy: 0.4495 - val_loss: 0.1683 - val_top3_acc: 0.6835 - val_top5_acc: 0.7869 - learning_rate: 5.0000e-04
# Epoch 45/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4124 - loss: 0.2751 - top3_acc: 0.6236 - top5_acc: 0.7181 - val_accuracy: 0.4232 - val_loss: 0.1631 - val_top3_acc: 0.6431 - val_top5_acc: 0.7444 - learning_rate: 2.5000e-04
# Epoch 46/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4117 - loss: 0.2732 - top3_acc: 0.6241 - top5_acc: 0.7181 - val_accuracy: 0.4051 - val_loss: 0.1615 - val_top3_acc: 0.6209 - val_top5_acc: 0.7152 - learning_rate: 2.5000e-04
# Epoch 47/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4133 - loss: 0.2729 - top3_acc: 0.6226 - top5_acc: 0.7174 - val_accuracy: 0.4567 - val_loss: 0.1617 - val_top3_acc: 0.6928 - val_top5_acc: 0.8041 - learning_rate: 2.5000e-04
# Epoch 48/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4125 - loss: 0.2722 - top3_acc: 0.6232 - top5_acc: 0.7168 - val_accuracy: 0.4264 - val_loss: 0.1601 - val_top3_acc: 0.6273 - val_top5_acc: 0.7057 - learning_rate: 2.5000e-04
# Epoch 49/120
# 977/977 - 6s - 7ms/step - accuracy: 0.4127 - loss: 0.2721 - top3_acc: 0.6241 - top5_acc: 0.7181 - val_accuracy: 0.4377 - val_loss: 0.1594 - val_top3_acc: 0.6430 - val_top5_acc: 0.7440 - learning_rate: 2.5000e-04
# Epoch 50/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4130 - loss: 0.2715 - top3_acc: 0.6242 - top5_acc: 0.7179 - val_accuracy: 0.4528 - val_loss: 0.1605 - val_top3_acc: 0.6959 - val_top5_acc: 0.8132 - learning_rate: 2.5000e-04
# Epoch 51/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4133 - loss: 0.2711 - top3_acc: 0.6242 - top5_acc: 0.7181 - val_accuracy: 0.4430 - val_loss: 0.1586 - val_top3_acc: 0.6581 - val_top5_acc: 0.7703 - learning_rate: 2.5000e-04
# Epoch 52/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4140 - loss: 0.2713 - top3_acc: 0.6243 - top5_acc: 0.7181 - val_accuracy: 0.4419 - val_loss: 0.1598 - val_top3_acc: 0.6447 - val_top5_acc: 0.7401 - learning_rate: 2.5000e-04
# Epoch 53/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4137 - loss: 0.2704 - top3_acc: 0.6242 - top5_acc: 0.7183 - val_accuracy: 0.4300 - val_loss: 0.1590 - val_top3_acc: 0.6524 - val_top5_acc: 0.7479 - learning_rate: 2.5000e-04
# Epoch 54/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4130 - loss: 0.2702 - top3_acc: 0.6233 - top5_acc: 0.7174 - val_accuracy: 0.4273 - val_loss: 0.1598 - val_top3_acc: 0.6352 - val_top5_acc: 0.7277 - learning_rate: 2.5000e-04
# Epoch 55/120
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 977/977 - 6s - 6ms/step - accuracy: 0.4127 - loss: 0.2703 - top3_acc: 0.6227 - top5_acc: 0.7166 - val_accuracy: 0.4481 - val_loss: 0.1586 - val_top3_acc: 0.6758 - val_top5_acc: 0.7872 - learning_rate: 2.5000e-04
# Epoch 56/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4147 - loss: 0.2665 - top3_acc: 0.6245 - top5_acc: 0.7185 - val_accuracy: 0.4536 - val_loss: 0.1551 - val_top3_acc: 0.6759 - val_top5_acc: 0.7789 - learning_rate: 1.2500e-04
# Epoch 57/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4146 - loss: 0.2658 - top3_acc: 0.6241 - top5_acc: 0.7181 - val_accuracy: 0.4241 - val_loss: 0.1547 - val_top3_acc: 0.6414 - val_top5_acc: 0.7453 - learning_rate: 1.2500e-04
# Epoch 58/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4136 - loss: 0.2654 - top3_acc: 0.6258 - top5_acc: 0.7190 - val_accuracy: 0.4195 - val_loss: 0.1548 - val_top3_acc: 0.6238 - val_top5_acc: 0.7101 - learning_rate: 1.2500e-04
# Epoch 59/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4146 - loss: 0.2652 - top3_acc: 0.6243 - top5_acc: 0.7184 - val_accuracy: 0.4291 - val_loss: 0.1547 - val_top3_acc: 0.6332 - val_top5_acc: 0.7231 - learning_rate: 1.2500e-04
# Epoch 60/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4138 - loss: 0.2649 - top3_acc: 0.6240 - top5_acc: 0.7172 - val_accuracy: 0.4381 - val_loss: 0.1543 - val_top3_acc: 0.6382 - val_top5_acc: 0.7203 - learning_rate: 1.2500e-04
# Epoch 61/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4138 - loss: 0.2648 - top3_acc: 0.6250 - top5_acc: 0.7189 - val_accuracy: 0.4483 - val_loss: 0.1532 - val_top3_acc: 0.6482 - val_top5_acc: 0.7390 - learning_rate: 1.2500e-04
# Epoch 62/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4147 - loss: 0.2645 - top3_acc: 0.6250 - top5_acc: 0.7191 - val_accuracy: 0.4259 - val_loss: 0.1529 - val_top3_acc: 0.6491 - val_top5_acc: 0.7516 - learning_rate: 1.2500e-04
# Epoch 63/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4152 - loss: 0.2644 - top3_acc: 0.6237 - top5_acc: 0.7174 - val_accuracy: 0.4324 - val_loss: 0.1541 - val_top3_acc: 0.6367 - val_top5_acc: 0.7312 - learning_rate: 1.2500e-04
# Epoch 64/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4143 - loss: 0.2637 - top3_acc: 0.6253 - top5_acc: 0.7190 - val_accuracy: 0.4329 - val_loss: 0.1532 - val_top3_acc: 0.6285 - val_top5_acc: 0.7131 - learning_rate: 1.2500e-04
# Epoch 65/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4143 - loss: 0.2635 - top3_acc: 0.6246 - top5_acc: 0.7188 - val_accuracy: 0.4365 - val_loss: 0.1527 - val_top3_acc: 0.6758 - val_top5_acc: 0.7893 - learning_rate: 1.2500e-04
# Epoch 66/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4143 - loss: 0.2639 - top3_acc: 0.6251 - top5_acc: 0.7191 - val_accuracy: 0.4269 - val_loss: 0.1527 - val_top3_acc: 0.6410 - val_top5_acc: 0.7468 - learning_rate: 1.2500e-04
# Epoch 67/120
# 977/977 - 11s - 11ms/step - accuracy: 0.4145 - loss: 0.2641 - top3_acc: 0.6252 - top5_acc: 0.7193 - val_accuracy: 0.4259 - val_loss: 0.1529 - val_top3_acc: 0.6248 - val_top5_acc: 0.7201 - learning_rate: 1.2500e-04
# Epoch 68/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4152 - loss: 0.2634 - top3_acc: 0.6245 - top5_acc: 0.7175 - val_accuracy: 0.4266 - val_loss: 0.1518 - val_top3_acc: 0.6553 - val_top5_acc: 0.7657 - learning_rate: 1.2500e-04
# Epoch 69/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4141 - loss: 0.2631 - top3_acc: 0.6244 - top5_acc: 0.7176 - val_accuracy: 0.4332 - val_loss: 0.1531 - val_top3_acc: 0.6270 - val_top5_acc: 0.7110 - learning_rate: 1.2500e-04
# Epoch 70/120
# 977/977 - 10s - 10ms/step - accuracy: 0.4138 - loss: 0.2632 - top3_acc: 0.6234 - top5_acc: 0.7174 - val_accuracy: 0.4366 - val_loss: 0.1515 - val_top3_acc: 0.6288 - val_top5_acc: 0.7197 - learning_rate: 1.2500e-04
# Epoch 71/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4155 - loss: 0.2633 - top3_acc: 0.6250 - top5_acc: 0.7195 - val_accuracy: 0.4384 - val_loss: 0.1513 - val_top3_acc: 0.6547 - val_top5_acc: 0.7578 - learning_rate: 1.2500e-04
# Epoch 72/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4134 - loss: 0.2626 - top3_acc: 0.6235 - top5_acc: 0.7174 - val_accuracy: 0.4290 - val_loss: 0.1509 - val_top3_acc: 0.6258 - val_top5_acc: 0.7158 - learning_rate: 1.2500e-04
# Epoch 73/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4147 - loss: 0.2625 - top3_acc: 0.6248 - top5_acc: 0.7184 - val_accuracy: 0.4346 - val_loss: 0.1513 - val_top3_acc: 0.6427 - val_top5_acc: 0.7430 - learning_rate: 1.2500e-04
# Epoch 74/120
# 977/977 - 11s - 11ms/step - accuracy: 0.4150 - loss: 0.2625 - top3_acc: 0.6244 - top5_acc: 0.7185 - val_accuracy: 0.4344 - val_loss: 0.1511 - val_top3_acc: 0.6361 - val_top5_acc: 0.7228 - learning_rate: 1.2500e-04
# Epoch 75/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4144 - loss: 0.2623 - top3_acc: 0.6245 - top5_acc: 0.7181 - val_accuracy: 0.4513 - val_loss: 0.1521 - val_top3_acc: 0.6652 - val_top5_acc: 0.7664 - learning_rate: 1.2500e-04
# Epoch 76/120
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 977/977 - 6s - 6ms/step - accuracy: 0.4147 - loss: 0.2624 - top3_acc: 0.6247 - top5_acc: 0.7182 - val_accuracy: 0.4350 - val_loss: 0.1510 - val_top3_acc: 0.6431 - val_top5_acc: 0.7379 - learning_rate: 1.2500e-04
# Epoch 77/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4157 - loss: 0.2610 - top3_acc: 0.6242 - top5_acc: 0.7179 - val_accuracy: 0.4249 - val_loss: 0.1490 - val_top3_acc: 0.6278 - val_top5_acc: 0.7176 - learning_rate: 6.2500e-05
# Epoch 78/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4149 - loss: 0.2597 - top3_acc: 0.6259 - top5_acc: 0.7193 - val_accuracy: 0.4291 - val_loss: 0.1483 - val_top3_acc: 0.6200 - val_top5_acc: 0.6990 - learning_rate: 6.2500e-05
# Epoch 79/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4149 - loss: 0.2598 - top3_acc: 0.6255 - top5_acc: 0.7192 - val_accuracy: 0.4382 - val_loss: 0.1495 - val_top3_acc: 0.6486 - val_top5_acc: 0.7437 - learning_rate: 6.2500e-05
# Epoch 80/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4153 - loss: 0.2594 - top3_acc: 0.6246 - top5_acc: 0.7174 - val_accuracy: 0.4297 - val_loss: 0.1495 - val_top3_acc: 0.6490 - val_top5_acc: 0.7471 - learning_rate: 6.2500e-05
# Epoch 81/120
# 977/977 - 10s - 10ms/step - accuracy: 0.4152 - loss: 0.2592 - top3_acc: 0.6244 - top5_acc: 0.7173 - val_accuracy: 0.4360 - val_loss: 0.1477 - val_top3_acc: 0.6568 - val_top5_acc: 0.7583 - learning_rate: 6.2500e-05
# Epoch 82/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4155 - loss: 0.2594 - top3_acc: 0.6250 - top5_acc: 0.7194 - val_accuracy: 0.4341 - val_loss: 0.1484 - val_top3_acc: 0.6529 - val_top5_acc: 0.7528 - learning_rate: 6.2500e-05
# Epoch 83/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4156 - loss: 0.2598 - top3_acc: 0.6254 - top5_acc: 0.7184 - val_accuracy: 0.4275 - val_loss: 0.1485 - val_top3_acc: 0.6219 - val_top5_acc: 0.7120 - learning_rate: 6.2500e-05
# Epoch 84/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4145 - loss: 0.2595 - top3_acc: 0.6241 - top5_acc: 0.7179 - val_accuracy: 0.4326 - val_loss: 0.1478 - val_top3_acc: 0.6571 - val_top5_acc: 0.7579 - learning_rate: 6.2500e-05
# Epoch 85/120
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 977/977 - 6s - 6ms/step - accuracy: 0.4159 - loss: 0.2593 - top3_acc: 0.6261 - top5_acc: 0.7195 - val_accuracy: 0.4186 - val_loss: 0.1482 - val_top3_acc: 0.6275 - val_top5_acc: 0.7169 - learning_rate: 6.2500e-05
# Epoch 86/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4143 - loss: 0.2583 - top3_acc: 0.6258 - top5_acc: 0.7190 - val_accuracy: 0.4117 - val_loss: 0.1468 - val_top3_acc: 0.6284 - val_top5_acc: 0.7283 - learning_rate: 3.1250e-05
# Epoch 87/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4156 - loss: 0.2578 - top3_acc: 0.6256 - top5_acc: 0.7184 - val_accuracy: 0.4250 - val_loss: 0.1467 - val_top3_acc: 0.6300 - val_top5_acc: 0.7217 - learning_rate: 3.1250e-05
# Epoch 88/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4160 - loss: 0.2577 - top3_acc: 0.6252 - top5_acc: 0.7188 - val_accuracy: 0.4255 - val_loss: 0.1463 - val_top3_acc: 0.6288 - val_top5_acc: 0.7171 - learning_rate: 3.1250e-05
# Epoch 89/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4156 - loss: 0.2577 - top3_acc: 0.6254 - top5_acc: 0.7183 - val_accuracy: 0.4282 - val_loss: 0.1469 - val_top3_acc: 0.6320 - val_top5_acc: 0.7252 - learning_rate: 3.1250e-05
# Epoch 90/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4151 - loss: 0.2581 - top3_acc: 0.6255 - top5_acc: 0.7184 - val_accuracy: 0.4292 - val_loss: 0.1463 - val_top3_acc: 0.6446 - val_top5_acc: 0.7415 - learning_rate: 3.1250e-05
# Epoch 91/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4161 - loss: 0.2571 - top3_acc: 0.6250 - top5_acc: 0.7180 - val_accuracy: 0.4232 - val_loss: 0.1466 - val_top3_acc: 0.6327 - val_top5_acc: 0.7237 - learning_rate: 3.1250e-05
# Epoch 92/120
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 977/977 - 6s - 6ms/step - accuracy: 0.4161 - loss: 0.2574 - top3_acc: 0.6255 - top5_acc: 0.7189 - val_accuracy: 0.4207 - val_loss: 0.1471 - val_top3_acc: 0.6409 - val_top5_acc: 0.7418 - learning_rate: 3.1250e-05
# Epoch 93/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4160 - loss: 0.2570 - top3_acc: 0.6254 - top5_acc: 0.7183 - val_accuracy: 0.4230 - val_loss: 0.1459 - val_top3_acc: 0.6303 - val_top5_acc: 0.7232 - learning_rate: 1.5625e-05
# Epoch 94/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4158 - loss: 0.2573 - top3_acc: 0.6248 - top5_acc: 0.7181 - val_accuracy: 0.4232 - val_loss: 0.1457 - val_top3_acc: 0.6215 - val_top5_acc: 0.7086 - learning_rate: 1.5625e-05
# Epoch 95/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4157 - loss: 0.2571 - top3_acc: 0.6258 - top5_acc: 0.7194 - val_accuracy: 0.4250 - val_loss: 0.1457 - val_top3_acc: 0.6306 - val_top5_acc: 0.7219 - learning_rate: 1.5625e-05
# Epoch 96/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4161 - loss: 0.2572 - top3_acc: 0.6252 - top5_acc: 0.7186 - val_accuracy: 0.4237 - val_loss: 0.1456 - val_top3_acc: 0.6238 - val_top5_acc: 0.7147 - learning_rate: 1.5625e-05
# Epoch 97/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4160 - loss: 0.2572 - top3_acc: 0.6257 - top5_acc: 0.7191 - val_accuracy: 0.4185 - val_loss: 0.1461 - val_top3_acc: 0.6234 - val_top5_acc: 0.7147 - learning_rate: 1.5625e-05
# Epoch 98/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4160 - loss: 0.2568 - top3_acc: 0.6260 - top5_acc: 0.7192 - val_accuracy: 0.4168 - val_loss: 0.1455 - val_top3_acc: 0.6259 - val_top5_acc: 0.7220 - learning_rate: 1.5625e-05
# Epoch 99/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4167 - loss: 0.2567 - top3_acc: 0.6260 - top5_acc: 0.7195 - val_accuracy: 0.4229 - val_loss: 0.1454 - val_top3_acc: 0.6261 - val_top5_acc: 0.7194 - learning_rate: 1.5625e-05
# Epoch 100/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4156 - loss: 0.2566 - top3_acc: 0.6250 - top5_acc: 0.7188 - val_accuracy: 0.4217 - val_loss: 0.1457 - val_top3_acc: 0.6240 - val_top5_acc: 0.7192 - learning_rate: 1.5625e-05
# Epoch 101/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4164 - loss: 0.2565 - top3_acc: 0.6251 - top5_acc: 0.7193 - val_accuracy: 0.4206 - val_loss: 0.1455 - val_top3_acc: 0.6264 - val_top5_acc: 0.7160 - learning_rate: 1.5625e-05
# Epoch 102/120
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1e-05.
# 977/977 - 6s - 6ms/step - accuracy: 0.4165 - loss: 0.2566 - top3_acc: 0.6258 - top5_acc: 0.7193 - val_accuracy: 0.4186 - val_loss: 0.1454 - val_top3_acc: 0.6221 - val_top5_acc: 0.7134 - learning_rate: 1.5625e-05
# Epoch 103/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4166 - loss: 0.2563 - top3_acc: 0.6255 - top5_acc: 0.7201 - val_accuracy: 0.4290 - val_loss: 0.1456 - val_top3_acc: 0.6268 - val_top5_acc: 0.7158 - learning_rate: 1.0000e-05
# Epoch 104/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4168 - loss: 0.2567 - top3_acc: 0.6254 - top5_acc: 0.7189 - val_accuracy: 0.4262 - val_loss: 0.1453 - val_top3_acc: 0.6273 - val_top5_acc: 0.7174 - learning_rate: 1.0000e-05
# Epoch 105/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4165 - loss: 0.2560 - top3_acc: 0.6259 - top5_acc: 0.7186 - val_accuracy: 0.4218 - val_loss: 0.1454 - val_top3_acc: 0.6269 - val_top5_acc: 0.7171 - learning_rate: 1.0000e-05
# Epoch 106/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4165 - loss: 0.2565 - top3_acc: 0.6264 - top5_acc: 0.7193 - val_accuracy: 0.4224 - val_loss: 0.1449 - val_top3_acc: 0.6233 - val_top5_acc: 0.7150 - learning_rate: 1.0000e-05
# Epoch 107/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4162 - loss: 0.2562 - top3_acc: 0.6253 - top5_acc: 0.7196 - val_accuracy: 0.4215 - val_loss: 0.1450 - val_top3_acc: 0.6235 - val_top5_acc: 0.7153 - learning_rate: 1.0000e-05
# Epoch 108/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4164 - loss: 0.2562 - top3_acc: 0.6255 - top5_acc: 0.7197 - val_accuracy: 0.4220 - val_loss: 0.1453 - val_top3_acc: 0.6282 - val_top5_acc: 0.7218 - learning_rate: 1.0000e-05
# Epoch 109/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4166 - loss: 0.2565 - top3_acc: 0.6258 - top5_acc: 0.7196 - val_accuracy: 0.4219 - val_loss: 0.1451 - val_top3_acc: 0.6237 - val_top5_acc: 0.7160 - learning_rate: 1.0000e-05
# Epoch 110/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4167 - loss: 0.2560 - top3_acc: 0.6254 - top5_acc: 0.7184 - val_accuracy: 0.4242 - val_loss: 0.1452 - val_top3_acc: 0.6323 - val_top5_acc: 0.7274 - learning_rate: 1.0000e-05
# Epoch 111/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4159 - loss: 0.2559 - top3_acc: 0.6253 - top5_acc: 0.7189 - val_accuracy: 0.4240 - val_loss: 0.1453 - val_top3_acc: 0.6228 - val_top5_acc: 0.7123 - learning_rate: 1.0000e-05
# Epoch 112/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4156 - loss: 0.2562 - top3_acc: 0.6252 - top5_acc: 0.7180 - val_accuracy: 0.4260 - val_loss: 0.1452 - val_top3_acc: 0.6240 - val_top5_acc: 0.7108 - learning_rate: 1.0000e-05
# Epoch 113/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4178 - loss: 0.2561 - top3_acc: 0.6265 - top5_acc: 0.7197 - val_accuracy: 0.4178 - val_loss: 0.1451 - val_top3_acc: 0.6251 - val_top5_acc: 0.7189 - learning_rate: 1.0000e-05
# Epoch 114/120
# 977/977 - 10s - 10ms/step - accuracy: 0.4163 - loss: 0.2560 - top3_acc: 0.6267 - top5_acc: 0.7197 - val_accuracy: 0.4264 - val_loss: 0.1451 - val_top3_acc: 0.6327 - val_top5_acc: 0.7245 - learning_rate: 1.0000e-05
# Epoch 115/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4171 - loss: 0.2562 - top3_acc: 0.6256 - top5_acc: 0.7201 - val_accuracy: 0.4270 - val_loss: 0.1452 - val_top3_acc: 0.6271 - val_top5_acc: 0.7186 - learning_rate: 1.0000e-05
# Epoch 116/120
# 977/977 - 6s - 6ms/step - accuracy: 0.4155 - loss: 0.2558 - top3_acc: 0.6244 - top5_acc: 0.7183 - val_accuracy: 0.4204 - val_loss: 0.1449 - val_top3_acc: 0.6257 - val_top5_acc: 0.7219 - learning_rate: 1.0000e-05
# Epoch 116: early stopping
# Restoring model weights from the end of the best epoch: 106.

# %%
# =========================================================================
# 4. AVALIAÇÃO TEXTUAL — métricas para copiar/colar e comparar entre versões
#
# Com soft targets, y_train/val/test são distribuições de probabilidade.
# - model.evaluate retorna KLD (não cross-entropy) — magnitudes diferentes.
#   O que importa é a tendência (descendo) e o gap treino/val.
# - CategoricalAccuracy e TopKCategoricalAccuracy fazem argmax(y_true)
#   internamente, então top-1/top-3/top-5 continuam interpretáveis como
#   "o modelo escolheu a melhor jogada do Minimax no top-K?".
# =========================================================================

def avalia_conjunto(nome, X, y_soft):
    m = model.evaluate(X, y_soft, verbose=0, return_dict=True)
    return {
        'conjunto': nome,
        'amostras': X.shape[0],
        'kld_loss':  m['loss'],
        'top1_acc':  m['accuracy'],
        'top3_acc':  m['top3_acc'],
        'top5_acc':  m['top5_acc'],
    }

resultados = pd.DataFrame([
    avalia_conjunto('Treino',    X_train, y_train),
    avalia_conjunto('Validação', X_val,   y_val),
    avalia_conjunto('Teste',     X_test,  y_test),
])
print("=" * 70)
print("RESUMO DE DESEMPENHO (BoxNet v3 — soft targets / KL Divergence)")
print("=" * 70)
print(resultados.to_string(index=False, float_format=lambda v: f"{v:.4f}"))

gap_top1 = resultados.loc[0, 'top1_acc'] - resultados.loc[1, 'top1_acc']
gap_kld  = resultados.loc[1, 'kld_loss'] - resultados.loc[0, 'kld_loss']
print(f"\nGap top1 (Treino - Val): {gap_top1*100:+.2f} pp   [< 5 pp saudável; > 10 pp = overfit]")
print(f"Gap KLD  (Val - Treino): {gap_kld:+.4f}")

ult = len(history.history['loss']) - 1
print(f"\nÚltima época: {ult+1}")
print(f"  kld_loss  treino={history.history['loss'][ult]:.4f}  val={history.history['val_loss'][ult]:.4f}")
print(f"  top1_acc  treino={history.history['accuracy'][ult]:.4f}  val={history.history['val_accuracy'][ult]:.4f}")

# =========================================================================
# Classification report — usa argmax do soft target como rótulo verdadeiro
# (argmax do Q-value = melhor jogada do Minimax, mesma semântica de antes)
# =========================================================================
y_pred_prob = model.predict(X_test, verbose=0)
y_pred_idx  = y_pred_prob.argmax(axis=1)

print("\n" + "=" * 70)
print("CLASSIFICATION REPORT (conjunto de TESTE)")
print("=" * 70)
report = classification_report(
    y_test_idx, y_pred_idx,
    labels=list(range(num_classes)),
    target_names=[indice_para_rotulo[i] for i in range(num_classes)],
    digits=4, zero_division=0, output_dict=True,
)
print(f"  accuracy:      {report['accuracy']:.4f}")
print(f"  macro avg:     P={report['macro avg']['precision']:.4f}  "
      f"R={report['macro avg']['recall']:.4f}  F1={report['macro avg']['f1-score']:.4f}")
print(f"  weighted avg:  P={report['weighted avg']['precision']:.4f}  "
      f"R={report['weighted avg']['recall']:.4f}  F1={report['weighted avg']['f1-score']:.4f}")

por_classe = pd.DataFrame({
    rotulo: report[rotulo]
    for rotulo in [indice_para_rotulo[i] for i in range(num_classes)]
}).T
por_classe.index.name = 'jogada'
por_classe = por_classe.sort_values('f1-score', ascending=False)

print("\nTop 10 jogadas com melhor F1 (onde o modelo brilha):")
print(por_classe.head(10)[['precision', 'recall', 'f1-score', 'support']]
      .to_string(float_format=lambda v: f"{v:.4f}"))
print("\nBottom 5 jogadas (onde o modelo mais erra — verificar bordas):")
print(por_classe.tail(5)[['precision', 'recall', 'f1-score', 'support']]
      .to_string(float_format=lambda v: f"{v:.4f}"))

# =========================================================================
# Gráficos de treino
# =========================================================================
fig, axes = plt.subplots(1, 3, figsize=(18, 4.5))

axes[0].plot(history.history['accuracy'],     label='Treino')
axes[0].plot(history.history['val_accuracy'], label='Validação')
axes[0].set_title('Top-1 Accuracy')
axes[0].set_xlabel('Época'); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history['top3_acc'],     label='Treino')
axes[1].plot(history.history['val_top3_acc'], label='Validação')
axes[1].set_title('Top-3 Accuracy')
axes[1].set_xlabel('Época'); axes[1].legend(); axes[1].grid(True)

axes[2].plot(history.history['loss'],     label='Treino (KLD)')
axes[2].plot(history.history['val_loss'], label='Validação (KLD)')
axes[2].set_title('KL Divergence Loss')
axes[2].set_xlabel('Época'); axes[2].legend(); axes[2].grid(True)

plt.suptitle('BoxNet v3 — Soft Targets / KL Divergence', fontsize=13)
plt.tight_layout(); plt.show()
# =========================================================================
# 5. METRICAS DIAGNOSTICAS EXTRAS
# =========================================================================

# 5.1  Top-1 / Top-3 por fase do jogo
# Conta tracados preenchidos nas posicoes H (r par, c impar) e V (r impar, c par)
mascara_tracos = np.zeros((9, 7), dtype=bool)
for _r in range(9):
    for _c in range(7):
        if (_r % 2 == 0 and _c % 2 == 1) or (_r % 2 == 1 and _c % 2 == 0):
            mascara_tracos[_r, _c] = True
tracos_jogados = (X_test[:, :, :, 0] != 0)[:, mascara_tracos].sum(axis=1)

fases = [
    (0,   9, 'Abertura (0-9 tracos)'),
    (10, 17, '1ª Metade (10-17 tracos)'),
    (18, 25, '2ª Metade (18-25 tracos)'),
    (26, 31, 'Final (21-31 tracos)'),
]
print('\n' + '=' * 70)
print('TOP-1 / TOP-3 ACCURACY POR FASE DO JOGO')
print('=' * 70)
print(f"  {'Fase':<28}  {'N':>6}  {'Top-1':>7}  {'Top-3':>7}")
for lo, hi, nome in fases:
    mask = (tracos_jogados >= lo) & (tracos_jogados <= hi)
    if mask.sum() == 0:
        continue
    t1 = (y_pred_idx[mask] == y_test_idx[mask]).mean()
    top3_pred = np.argsort(y_pred_prob[mask], axis=1)[:, -3:]
    t3 = (top3_pred == y_test_idx[mask, np.newaxis]).any(axis=1).mean()
    print(f"  {nome:<28}  {mask.sum():>6}  {t1:>6.1%}  {t3:>6.1%}")

# 5.2  Optimal Move Accuracy
# A previsao top-1 pertence ao conjunto de jogadas Minimax-otimas?
# S_test contem Q-values brutos; otimo = score == max_score (e slot disponivel)
max_scores_test = S_test.max(axis=1, keepdims=True)
eh_otimo       = (S_test == max_scores_test) & (S_test > -1e8)
pred_eh_otimo  = eh_otimo[np.arange(len(y_pred_idx)), y_pred_idx]
optimal_acc    = pred_eh_otimo.mean()
media_equiv    = eh_otimo.sum(axis=1).mean()
print(f'\n  Optimal Move Accuracy (previsao in conjunto Minimax-otimo): {optimal_acc:.1%}')
print(f'  Media de jogadas Minimax-equivalentes por estado: {media_equiv:.1f}')
print()
# Out:
# ======================================================================
# RESUMO DE DESEMPENHO (BoxNet v3 — soft targets / KL Divergence)
# ======================================================================
#  conjunto  amostras  kld_loss  top1_acc  top3_acc  top5_acc
#    Treino    249900    0.1436    0.4246    0.6235    0.7140
# Validação     53550    0.1449    0.4224    0.6233    0.7150
#     Teste     53550    0.1455    0.4272    0.6241    0.7164
#
# Gap top1 (Treino - Val): +0.23 pp   [< 5 pp saudável; > 10 pp = overfit]
# Gap KLD  (Val - Treino): +0.0013
#
# Última época: 116
#   kld_loss  treino=0.2558  val=0.1449
#   top1_acc  treino=0.4155  val=0.4204
#
# ======================================================================
# CLASSIFICATION REPORT (conjunto de TESTE)
# ======================================================================
#   accuracy:      0.4272
#   macro avg:     P=0.4468  R=0.6248  F1=0.4811
#   weighted avg:  P=0.5738  R=0.4272  F1=0.3860
#
# Top 10 jogadas com melhor F1 (onde o modelo brilha):
#         precision  recall  f1-score   support
# jogada
# H_4_5      0.5664  0.7368    0.6404 1083.0000
# V_7_2      0.5206  0.7834    0.6255  937.0000
# H_2_3      0.6182  0.6079    0.6130 1441.0000
# H_2_1      0.6114  0.6103    0.6108 1578.0000
# H_6_1      0.4964  0.7672    0.6028 1001.0000
# V_7_4      0.4548  0.8647    0.5961  791.0000
# H_6_5      0.4741  0.8016    0.5958  902.0000
# H_2_5      0.5384  0.6547    0.5909 1306.0000
# V_1_4      0.6507  0.5297    0.5840 1871.0000
# V_3_2      0.5101  0.6538    0.5731 1274.0000
#
# Bottom 5 jogadas (onde o modelo mais erra — verificar bordas):
#         precision  recall  f1-score    support
# jogada
# H_0_5      0.5261  0.2433    0.3327  3440.0000
# V_5_0      0.2315  0.5740    0.3299  1047.0000
# V_3_6      0.2018  0.5794    0.2994   982.0000
# H_0_3      0.4403  0.1634    0.2384  5641.0000
# H_0_1      0.9349  0.0889    0.1624 13236.0000
# ======================================================================
# TOP-1 / TOP-3 ACCURACY POR FASE DO JOGO
# ======================================================================
#   Fase                               N    Top-1    Top-3
#   Abertura (0-9 tracos)          13890    8.0%   15.1%
#   1ª Metade (10-17 tracos)       18696   40.9%   65.9%
#   2ª Metade (18-25 tracos)       18641   67.8%   90.7%
#   Final (21-31 tracos)            2323   63.8%   90.5%
#
#   Optimal Move Accuracy (previsao in conjunto Minimax-otimo): 93.2%
#   Media de jogadas Minimax-equivalentes por estado: 7.2

# %%
# =========================================================================
# 5.3 VISUALIZAÇÃO POR FASE (Gráfico Comparativo)
# =========================================================================
dados_fases = []
for lo, hi, nome in fases:
    mask = (tracos_jogados >= lo) & (tracos_jogados <= hi)
    if mask.sum() > 0:
        # Top-1
        t1 = (y_pred_idx[mask] == y_test_idx[mask]).mean()

        # Top-3 e Top-5
        argsorted_preds = np.argsort(y_pred_prob[mask], axis=1)
        top3_pred = argsorted_preds[:, -3:]
        top5_pred = argsorted_preds[:, -5:]

        t3 = (top3_pred == y_test_idx[mask, np.newaxis]).any(axis=1).mean()
        t5 = (top5_pred == y_test_idx[mask, np.newaxis]).any(axis=1).mean()

        fase_nome = nome.split(' ')[0]
        dados_fases.append({'Fase': fase_nome, 'Métrica': 'Top-1', 'Acurácia': t1})
        dados_fases.append({'Fase': fase_nome, 'Métrica': 'Top-3', 'Acurácia': t3})
        dados_fases.append({'Fase': fase_nome, 'Métrica': 'Top-5', 'Acurácia': t5})

df_fases = pd.DataFrame(dados_fases)

plt.figure(figsize=(12, 6))
sns.barplot(data=df_fases, x='Fase', y='Acurácia', hue='Métrica', palette='viridis')
plt.title('Performance Detalhada: Abertura vs Meio vs Final')
plt.ylim(0, 1.1)
plt.ylabel('Taxa de Acerto')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# =========================================================================
# EXPORTACAO PARA TENSORFLOW LITE
# =========================================================================
import shutil

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

nome_arquivo = 'pontinhos_pequeno_profundidade_9.tflite'

# 1) Salva localmente na instância Colab
with open(nome_arquivo, 'wb') as f:
    f.write(tflite_model)
print(f'Modelo salvo localmente: {nome_arquivo} ({len(tflite_model)/1024:.1f} KB)')

# 2) Copia para o Google Drive — persiste mesmo que a instância caia
drive_path = os.path.join(DRIVE_OUTPUT_DIR, nome_arquivo)
shutil.copy(nome_arquivo, drive_path)
print(f'Modelo salvo no Drive:   {drive_path}')

# 3) Oferece download direto (só funciona se a sessão ainda estiver ativa)
try:
    from google.colab import files
    files.download(nome_arquivo)
except Exception:
    print('Download automatico nao disponivel — use o arquivo salvo no Drive.')

# %%
# =========================================================================
# EXPORTACAO PARA TENSORFLOW LITE
# =========================================================================
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

nome_arquivo = 'pontinhos_pequeno_profundidade_8.tflite'
with open(nome_arquivo, 'wb') as f:
    f.write(tflite_model)
print(f'Modelo salvo: {nome_arquivo} ({len(tflite_model)/1024:.1f} KB)')

from google.colab import files
files.download(nome_arquivo)
# Out:
# Saved artifact at '/tmp/tmpe73hhjpz'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 9, 7, 1), dtype=tf.float32, name='tabuleiro_cru')
# Output Type:
#   TensorSpec(shape=(None, 31), dtype=tf.float32, name=None)
# Captures:
#   134269157315536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269156710864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269156711824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157311696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157316880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157313232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157314000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157317264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157316112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157315728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157317072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157316688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157319760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157316304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157320144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157321296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157320528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157319376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157320912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157321104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157316496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157321488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157320720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157318224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157322448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157320336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157321680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157322640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157323408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157323216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157322256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157323792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134269157323600: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Modelo salvo: pontinhos_pequeno_profundidade_8.tflite (92.0 KB)
